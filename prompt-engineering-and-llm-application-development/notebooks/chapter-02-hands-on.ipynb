# %%
# %pip install openai
# %pip install dotenv
# %pip install python-dotenv
# %pip install scraper
# Out:
# Requirement already satisfied: openai in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.24.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: dotenv in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.9.9)
# Requirement already satisfied: python-dotenv in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from dotenv) (1.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-dotenv in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scraper in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.1.0)
# Requirement already satisfied: lxml>=3.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from scraper) (6.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
from IPython.display import Markdown, display
from openai import OpenAI

# Load environment variables in a file called .env

load_dotenv(override=True)
API_KEY = os.getenv('OPENAI_API_KEY')

# Check the key
if (not API_KEY) or (not isinstance(API_KEY, str)):
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif (not API_KEY.startswith("sk-proj-")):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif (API_KEY.strip() != API_KEY):
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")

openai = OpenAI(api_key=API_KEY)
# Out:
# API key found and looks good so far!

# %%
prompt = "Write a creative tagline for an AI startup."

# %%
response = openai.responses.create(
    model="gpt-4.1-mini",
    input=prompt,
    max_output_tokens=30
)

display(Markdown(response.output_text))
# Out:
# “Intelligence that Innovates, Tomorrow that Transforms.”

# %%
response = openai.responses.create(
    model="gpt-4.1-mini",
    input=prompt,
    temperature=0.2,
    max_output_tokens=30
)

display(Markdown(response.output_text))
# Out:
# "Empowering Tomorrow, Intelligently Today."

# %%
response = openai.responses.create(
    model="gpt-4.1-mini",
    input=prompt,
    temperature=0.9,
    max_output_tokens=30
)

display(Markdown(response.output_text))
# Out:
# “Intelligence, Innovated.”

# %%
response = openai.responses.create(
    model="gpt-4.1-mini",
    input=prompt,
    top_p=0.6,
    temperature=1.0,
    max_output_tokens=30
)

display(Markdown(response.output_text))
# Out:
# "Empowering Tomorrow, One Algorithm at a Time."

# %%
top_ps = [0.2, 0.5, 0.8, 0.95]

for p in top_ps:
    
    response = openai.responses.create(
        model="gpt-4.1-mini",
        input=prompt,
        top_p=p,
        temperature=1.0,
        max_output_tokens=30
    )
    
    display(Markdown(f"\nTop_p = {p}"))
    display(Markdown(response.output_text))
# Out:
# Top_p = 0.2
# "Empowering Tomorrow, One Algorithm at a Time."
# Top_p = 0.5
# "Empowering Tomorrow, One Algorithm at a Time."
# Top_p = 0.8
# "Empowering Tomorrow, Intelligently."
# Top_p = 0.95
# "Empowering Tomorrow, One Algorithm at a Time."

# %% [markdown]
# ### END
